# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Bankruptcy Data.csv')

# %%
data.describe()
# Out:
#               fyear            X1            X2            X3            X4  \
# count  78682.000000  7.868200e+04  7.868200e+04  7.868200e+04  7.868200e+04
# mean    2007.506317  2.133141e+05  5.994709e+05  3.797745e+05  1.508433e+05
# std        5.742768  7.016291e+05  2.065452e+06  2.021659e+06  7.115052e+05
# min     1999.000000 -2.498000e+03  7.000000e-03 -3.666450e+05 -2.300000e+01
# 25%     2002.000000  1.272000e+03  3.282525e+03  1.439100e+03  0.000000e+00
# 50%     2007.000000  2.201650e+04  4.326650e+04  2.104450e+04  5.000000e+02
# 75%     2012.000000  1.539940e+05  3.293620e+05  1.808215e+05  1.601050e+04
# max     2018.000000  3.132258e+07  6.723494e+07  1.632456e+08  2.068708e+07
#
#                  X5            X6            X7            X8            X9  \
# count  7.868200e+04  7.868200e+04  7.868200e+04  7.868200e+04  7.868200e+04
# mean   2.471565e+04  4.426177e+04  6.942115e+04  1.723757e+05  5.102166e+04
# ...

# %%
data.head()
# Out:
#   company_name   fyear status_label        X1          X2        X3        X4  \
# 0          C_1  1999.0        alive  511267.0  740998.000  833107.0  180447.0
# 1          C_1  2000.0        alive  485856.0     701.854  713811.0  179987.0
# 2          C_1  2001.0        alive  436656.0  710199.000  526477.0  217699.0
# 3          C_1  2002.0        alive  396412.0     686.621  496747.0  164658.0
# 4          C_1  2003.0        alive  432204.0     709.292  523302.0  248666.0
#
#          X5        X6         X7  ...        X11         X12         X13  \
# 0  18373.00  70658.00  89031.000  ...     35.163  201026.000     128.348
# 1  18577.00     45.79  64367.000  ...  18531.000  204065.000  115187.000
# 2  22496.00   4711.00  27207.000  ...    -58.939     139.603   77528.000
# 3  27172.00   3573.00  30745.000  ...    -12.410  124106.000   66322.000
# 4     26.68  20811.00     47.491  ...   3504.000  131884.000  104661.000
#
# ...

# %%
len(data['company_name'].unique())
# Out:
# 8971

# %%
data['status_label'].unique()
# Out:
# array(['alive', 'failed'], dtype=object)

# %%
data.shape
# Out:
# (78682, 23)
